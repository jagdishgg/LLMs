# %%
from flask import Flask, request, jsonify
import base64
import io
from PIL import Image
import base64
import numpy as np
#import cv2
import time
import os
from matplotlib import pyplot as plt
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

from passporteye.mrz.image import MRZPipeline
import imageio.v3 as iio
import base64
from io import BytesIO
from PIL import Image
import random 
from datetime import date
from datetime import datetime

# %%
from flask import Flask, request, Response
#import jsonpickle
import numpy as np
#import cv2

# Initialize the Flask application
app = Flask(__name__)


# route http posts to this method
@app.route('/api/test', methods=['POST'])
def test():
    r = request
    # convert string of image data to uint8
    #encoded_data = np.frombuffer(r.data, np.uint8)
    #encoded_data = np.frombuffer(r.args['data'], np.uint8)
    # decode image
    
    encoded_data=r.args['data']
    print('below is the data before')
    print(encoded_data)
    print('**below is the data before')
    
    encoded_data=encoded_data.replace(' ','+')
    print('below2 is the data after2')
    #encoded_data = np.frombuffer(r.data, np.uint8)
    print(encoded_data)
    print('below2 is the data after2')
    
    now=datetime.now()
    file_name1 =(now.strftime('%d%m%Y%H%M%S')  + str (random.randint(1,1000)) )

    #img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    #decoded_data=base64.b64decode((encoded_data))
    #print(decoded_data)
    #img_file = open('image.png', 'wb')
    #img_file=imageio.imopen('file://image.png','w')
    #img_file.imwrite('image.png',decoded_data)
    #img_file.write(decoded_data)
    #img=iio.imread("file://newimage.jpeg")
    #iio.imwrite( decoded_data,img,extension=".jpeg")
    #img_file.close()
    #buf = io.BytesIO(decoded_data)
    #print('below is the data before2')
    #print(buf)
    #img_file = open('newimage2.jpeg', 'wb')
    #img_file.write(buf.getbuffer())
    #img_file.save()
    #img_file.close()
    #encoded_data='...'
    print('below2 is the data before')
    print(encoded_data)
    print('**below2 is the data before')
    image_data = bytes(encoded_data, encoding="ascii")
    im = Image.open(BytesIO(base64.b64decode(image_data)))
    #plt.imshow(im)
    im.save('image3.png')
    




    image_file="image3.png"
    p = MRZPipeline(image_file)
    mrz = p.result
    res=p.data['text']
    #return(res)
    if res ==None:
        res='mrz not found'
    # do some fancy processing here....

    # build a response dict to send back to client
    #response = {'message': 'image received. size={}x{}'.format(img.shape[1], img.shape[0])     }
    response={res}
    #response = {'message received': 'image received.'}
    # encode response using jsonpickle
    #response_pickled = jsonpickle.encode(response)

    return Response(response=response, status=200, mimetype="application/json")


# start flask app
app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://172.22.51.128:5000/ (Press CTRL+C to quit)
# below is the data before
# ...
